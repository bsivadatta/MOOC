# %% [markdown]
# # TEXT PREPROCESSING

# %% [markdown]
# Lets take pdf transcript files as input

# %%
import PyPDF2
pdfFileObj = open('lec2.pdf','rb')     #'rb' for read binary mode
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
n=pdfReader.numPages
output=''
for i in range(n-1):
    pageObj = pdfReader.getPage(i+1)          #'9' is the page number
    output=output+pageObj.extractText()

# %% [markdown]
# text has been extracted

# %%
import numpy as np

# %%
pageObj.extractText()
# Out:
# 'whatever we have made it here you can have a look and just see this is the way that \nthings can be\n I mean operatin\ng schedule can be prepared\n. '

# %%
type(pageObj.extractText())
# Out:
# str

# %%
output
text=output

# %% [markdown]
# ## Start Preprocessing

# %%
text=text.lower()       #convert to lower case

# %%
text=text.replace('\n','')     #remove all line breaks

# %%
text
# Out:
# '(refer slide time: 01:31)  so, it is the ratio of the sum of the individual maximum demand of the various sub divisions or groups or consumers to the maximum demand of the whole system. so, what is this? it is ratio of sum of individual maximum demands of the various subdivisions or groups or consumers to the maximum demand of the whole system for example, diversity at loop; diversity factor we are using system fd because demand factor we have used either (refer time: 02:03) df. so, that is why i have made fd. so, there should not be any confusion right. so, diversity factor we term it as fd is given as fd = [(sum of individual maximum demand)/(coincident maximum demand)]. or we can write suppose individual maximum demand says if p1 p2 p3 like this if they are the maximum demand for individual consumers right. so, diversity factor fd = [1niip/cp], "pi is the maximum demand of load i" right divide and "p c is equal to coincident maximum demand of group of n loads". so, this is equati
# ...

# %%
text=text.replace('refer slide time:','')
text=text.replace('refer time:','')                 #remove all slide times
text=text.replace('refer slide:','')

# %%
words = text.split()               
print(words[:100])
# Out:
# ['(', '01:31)', 'so,', 'it', 'is', 'the', 'ratio', 'of', 'the', 'sum', 'of', 'the', 'individual', 'maximum', 'demand', 'of', 'the', 'various', 'sub', 'divisions', 'or', 'groups', 'or', 'consumers', 'to', 'the', 'maximum', 'demand', 'of', 'the', 'whole', 'system.', 'so,', 'what', 'is', 'this?', 'it', 'is', 'ratio', 'of', 'sum', 'of', 'individual', 'maximum', 'demands', 'of', 'the', 'various', 'subdivisions', 'or', 'groups', 'or', 'consumers', 'to', 'the', 'maximum', 'demand', 'of', 'the', 'whole', 'system', 'for', 'example,', 'diversity', 'at', 'loop;', 'diversity', 'factor', 'we', 'are', 'using', 'system', 'fd', 'because', 'demand', 'factor', 'we', 'have', 'used', 'either', '(', '02:03)', 'df.', 'so,', 'that', 'is', 'why', 'i', 'have', 'made', 'fd.', 'so,', 'there', 'should', 'not', 'be', 'any', 'confusion', 'right.', 'so,']

# %%
words = text.split()
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in words]               #remove punctuations
print(stripped[:100])
# Out:
# ['so', 'now', 'ah', 'we', 'will', 'go', 'for', 'the', 'inductance', 'oftransmission', 'line', 'ah', 'the', 'basic', 'concepts', 'rightso', 'we', 'know', 'that', 'a', 'conductor', 'when', 'carryingcurrent', 'has', 'a', 'magnetic', 'field', 'around', 'a', 'it', 'rightfor', 'example', 'suppose', 'if', 'we', 'apply', 'right', 'handrule', 'suppose', 'if', 'this', 'is', 'your', 'co', 'is', 'if', 'thisis', 'your', 'conductor', 'right', 'and', 'if', 'you', 'have', 'theconductor', 'in', 'the', 'like', 'this', 'then', 'if', 'this', 'isthe', 'direction', 'of', 'the', 'current', 'flow', 'then', 'thisis', 'that', 'anti', 'clock', 'if', 'you', 'see', 'that', 'anticlockwisethis', 'is', 'the', 'direction', 'of', 'right', 'so', 'so', 'whenevera', 'conductor', 'carrying', 'current', 'it', 'has', 'a', 'magneticfield', 'around', 'it', 'right', 'so', 'the', 'magnetic', 'linesof']

# %%
words = [word for word in stripped if word.isalpha()]
import nltk
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]        #remove stop words
print(words[:100])
# Out:
# ['ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'sub', 'divisions', 'groups', 'consumers', 'maximum', 'demand', 'whole', 'system', 'ratio', 'sum', 'individual', 'maximum', 'demands', 'various', 'subdivisions', 'groups', 'consumers', 'maximum', 'demand', 'whole', 'system', 'example', 'diversity', 'loop', 'diversity', 'factor', 'using', 'system', 'fd', 'demand', 'factor', 'used', 'either', 'df', 'made', 'fd', 'confusion', 'right', 'diversity', 'factor', 'term', 'fd', 'given', 'fd', 'sum', 'individual', 'maximum', 'demandcoincident', 'maximum', 'demand', 'write', 'suppose', 'individual', 'maximum', 'demand', 'says', 'like', 'maximum', 'demand', 'individual', 'consumers', 'right', 'diversity', 'factor', 'fd', 'pi', 'maximum', 'demand', 'load', 'right', 'divide', 'p', 'c', 'equal', 'coincident', 'maximum', 'demand', 'group', 'n', 'loads', 'equation', 'diversity', 'factory', 'use', 'term', 'fd', 'df', 'demand', 'factor', 'df', 'earlier', 'used', 'actually', 'diversity']

# %% [markdown]
# from nltk.stem.porter import PorterStemmer
# porter = PorterStemmer()
# stemmed = [porter.stem(word) for word in words]
# print(stemmed[:100])

# %%
# import these modules 
from nltk.stem import WordNetLemmatizer 

lemmatizer = WordNetLemmatizer() 

lemmatized = [lemmatizer.lemmatize(word) for word in words]
print(lemmatized[:100])
# Out:
# ['ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'sub', 'division', 'group', 'consumer', 'maximum', 'demand', 'whole', 'system', 'ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'subdivision', 'group', 'consumer', 'maximum', 'demand', 'whole', 'system', 'example', 'diversity', 'loop', 'diversity', 'factor', 'using', 'system', 'fd', 'demand', 'factor', 'used', 'either', 'df', 'made', 'fd', 'confusion', 'right', 'diversity', 'factor', 'term', 'fd', 'given', 'fd', 'sum', 'individual', 'maximum', 'demandcoincident', 'maximum', 'demand', 'write', 'suppose', 'individual', 'maximum', 'demand', 'say', 'like', 'maximum', 'demand', 'individual', 'consumer', 'right', 'diversity', 'factor', 'fd', 'pi', 'maximum', 'demand', 'load', 'right', 'divide', 'p', 'c', 'equal', 'coincident', 'maximum', 'demand', 'group', 'n', 'load', 'equation', 'diversity', 'factory', 'use', 'term', 'fd', 'df', 'demand', 'factor', 'df', 'earlier', 'used', 'actually', 'diversity']

# %%
data=[]
for w in lemmatized:
    if(len(w)>1):
        data.append(w);

# %%
print(data[:100])
# Out:
# ['ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'sub', 'division', 'group', 'consumer', 'maximum', 'demand', 'whole', 'system', 'ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'subdivision', 'group', 'consumer', 'maximum', 'demand', 'whole', 'system', 'example', 'diversity', 'loop', 'diversity', 'factor', 'using', 'system', 'fd', 'demand', 'factor', 'used', 'either', 'df', 'made', 'fd', 'confusion', 'right', 'diversity', 'factor', 'term', 'fd', 'given', 'fd', 'sum', 'individual', 'maximum', 'demandcoincident', 'maximum', 'demand', 'write', 'suppose', 'individual', 'maximum', 'demand', 'say', 'like', 'maximum', 'demand', 'individual', 'consumer', 'right', 'diversity', 'factor', 'fd', 'pi', 'maximum', 'demand', 'load', 'right', 'divide', 'equal', 'coincident', 'maximum', 'demand', 'group', 'load', 'equation', 'diversity', 'factory', 'use', 'term', 'fd', 'df', 'demand', 'factor', 'df', 'earlier', 'used', 'actually', 'diversity', 'factor', 'next', 'understand
# ...

# %% [markdown]
# ## Complete Code with PDF Input

# %%
import PyPDF2
import numpy as np
pdfFileObj = open('lec2.pdf','rb')     #'rb' for read binary mode
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
n=pdfReader.numPages
output=''
for i in range(n-1):
    pageObj = pdfReader.getPage(i+1)          #'9' is the page number
    output=output+pageObj.extractText()
text=output    
text=text.lower()
text=text.replace('\n','')
text=text.replace('refer slide time:','')
text=text.replace('refer time:','')
text=text.replace('refer slide:','')
words = text.split()
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in words]

words = [word for word in stripped if word.isalpha()]
import nltk
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
from nltk.stem import WordNetLemmatizer 

lemmatizer = WordNetLemmatizer() 

lemmatized = [lemmatizer.lemmatize(word) for word in words]
print(lemmatized[:100])
data=[]
for w in lemmatized:
    if(len(w)>1):
        data.append(w);
# Out:
# ['ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'sub', 'division', 'group', 'consumer', 'maximum', 'demand', 'whole', 'system', 'ratio', 'sum', 'individual', 'maximum', 'demand', 'various', 'subdivision', 'group', 'consumer', 'maximum', 'demand', 'whole', 'system', 'example', 'diversity', 'loop', 'diversity', 'factor', 'using', 'system', 'fd', 'demand', 'factor', 'used', 'either', 'df', 'made', 'fd', 'confusion', 'right', 'diversity', 'factor', 'term', 'fd', 'given', 'fd', 'sum', 'individual', 'maximum', 'demandcoincident', 'maximum', 'demand', 'write', 'suppose', 'individual', 'maximum', 'demand', 'say', 'like', 'maximum', 'demand', 'individual', 'consumer', 'right', 'diversity', 'factor', 'fd', 'pi', 'maximum', 'demand', 'load', 'right', 'divide', 'p', 'c', 'equal', 'coincident', 'maximum', 'demand', 'group', 'n', 'load', 'equation', 'diversity', 'factory', 'use', 'term', 'fd', 'df', 'demand', 'factor', 'df', 'earlier', 'used', 'actually', 'diversity']

# %% [markdown]
# ## Complete code with .txt file as Input

# %%
import numpy as np
import os 
import os
import string
import nltk
# filter out stop words
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer 
total=[]
for filename in os.listdir(r'C:\Users\datta\Desktop\tfidf\srt'):
    if filename.endswith('.txt'):
            text = open((os.path.join(r'C:\Users\datta\Desktop\tfidf\srt', filename)),'r').read()
            
            
     #'rb' for read binary mode
#pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
#n=pdfReader.numPages
#print(n)
#output=''
#for i in range(n-1):
#    pageObj = pdfReader.getPage(i+1)          #'9' is the page number
#    output=output+pageObj.extractText()
#text=output
    text=text.lower()
    text=text.replace('\n','')
    text=text.replace('refer slide time:','')
    text=text.replace('refer time:','')
    text=text.replace('refer slide:','')
    words = text.split()
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in words]

    words = [word for word in stripped if word.isalpha()]
    stop_words = set(stopwords.words('english'))
    words = [w for w in words if not w in stop_words]

    lemmatizer = WordNetLemmatizer() 

    lemmatized = [lemmatizer.lemmatize(word) for word in words]
    data=[]
    for w in lemmatized:
        if(len(w)>1):
            data.append(w);
    total.append(data);

# %%
total
# Out:
# [['therefore',
#   'ah',
#   'plant',
#   'factor',
#   'plantfactor',
#   'equal',
#   'actual',
#   'energy',
#   'produceddivided',
#   'maximum',
#   'plant',
#   'rating',
#   'thisis',
#   'specify',
#   'time',
#   'isequation',
#   'three',
#   'plant',
#   'factor',
#   'mostly',
#   'usedin',
#   'genetics',
#   'ah',
#   'ah',
#   'generation',
#   'studiesit',
#   'also',
#   'given',
#   'annual',
#   'plant',
#   'factor',
#   'isequal',
#   'actual',
#   'energy',
#   'generation',
#   'maximumplant',
#   'rating',
#   'right',
#   'annual',
#   'plant',
#   'factorthat',
#   'actual',
#   'annual',
#   'energy',
#   'generation',
#   'maximumplant',
#   'rating',
#   'eight',
#   'seven',
#   'six',
#   'zero',
#   'ina',
#   'year',
#   'total',
#   'number',
#   'hour',
#   'eight',
#   'sevensix',
#   'zero',
#   'three',
#   'way',
#   'defined',
#   'oneis',
#   'actual',
#   'energy',
#   'generation',
#   'maximum',
#   'plantrating',
#   'actual',
# ...
